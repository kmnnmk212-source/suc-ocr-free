# %% [markdown]
# https://github.com/fabriziosalmi/pdf-ocr

# %%
# !sudo apt-get update && sudo apt-get install tesseract-ocr libtesseract-dev tesseract-ocr-all
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,014 kB]
# ...

# %%
# !sudo apt-get update && sudo apt-get install poppler-utils
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# !git clone https://github.com/fabriziosalmi/pdf-ocr.git
# Out:
# Cloning into 'pdf-ocr'...
# remote: Enumerating objects: 243, done.
# remote: Counting objects: 100% (243/243), done.
# remote: Compressing objects: 100% (190/190), done.
# remote: Total 243 (delta 110), reused 158 (delta 47), pack-reused 0 (from 0)
# Receiving objects: 100% (243/243), 29.30 MiB | 39.16 MiB/s, done.
# Resolving deltas: 100% (110/110), done.

# %%
# %cd pdf-ocr
# Out:
# /content/pdf-ocr

# %%
# !python install_dependencies.py
# Out:
# OCR PDF to DOCX Converter - Dependency Installer
# ...
#
# ==> Checking Python version
# ✓ Python version is compatible: 3.12.11
#
# ==> Checking pip installation
# ✓ pip is installed: pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
#
# ==> Installing core Python dependencies
# ℹ Installing pdf2image...
# ✓ pdf2image installed successfully
# ℹ Installing pytesseract...
# ✓ pytesseract installed successfully
# ℹ Installing other core dependencies...
# ℹ Installing Flask>=2.0.0...
# ℹ Installing werkzeug>=2.0.0...
# ℹ Installing python-docx>=0.8.11...
# ℹ Installing Pillow>=8.0.0...
# ℹ Installing gunicorn>=20.1.0...
# ℹ Installing python-dotenv>=0.19.0...
# ✓ Core Python dependencies installed successfully
#
# ==> Checking Tesseract OCR installation
# ✓ Tesseract OCR is installed: tesseract 4.1.1
#
# ==> Checking Poppler installation
# ✓ Poppler is installed
#
# ✓ Installation completed
# You can now run the application with: python app.py

# %%
# !python app.py
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: off
# 2025-09-29 18:07:00,857 - werkzeug - INFO - WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8011
#  * Running on http://172.28.0.12:8011
# 2025-09-29 18:07:00,857 - werkzeug - INFO - Press CTRL+C to quit

# %%
https://nodejs.org/docs/latest/api/synopsis.html
# !pip install pyngrok



from pyngrok import ngrok
import threading
import time

ngrok_token = "XXXXXXXXXXXXXXXXXXXXXXXXX"
ngrok.set_auth_token(ngrok_token)

# Start ngrok in a separate thread to avoid blocking
def start_ngrok():
    public_url = ngrok.connect(3000).public_url
    print(f"🚀 Ngrok Tunnel Open: {public_url}")

ngrok_thread = threading.Thread(target=start_ngrok)
ngrok_thread.start()

# Wait for ngrok to start (optional)
time.sleep(5)

# Execute your node.js script
# !node hello-world.js

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
import threading
import time

ngrok_token = "XXXXXXXXXXXXXXXXXXXXXXX"
ngrok.set_auth_token(ngrok_token)

# Start ngrok in a separate thread to avoid blocking
def start_ngrok():
    public_url = ngrok.connect(8011).public_url
    print(f"🚀 Ngrok Tunnel Open: {public_url}")

ngrok_thread = threading.Thread(target=start_ngrok)
ngrok_thread.start()

# Wait for ngrok to start (optional)
time.sleep(5)

# !python app.py
# Out:
# 🚀 Ngrok Tunnel Open: https://8f1bfcab916a.ngrok-free.app
#  * Serving Flask app 'app'
#  * Debug mode: off
# 2025-09-29 18:09:19,320 - werkzeug - INFO - WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8011
#  * Running on http://172.28.0.12:8011
# 2025-09-29 18:09:19,320 - werkzeug - INFO - Press CTRL+C to quit
# 2025-09-29 18:09:20,166 - werkzeug - INFO - 127.0.0.1 - - [29/Sep/2025 18:09:20] "GET / HTTP/1.1" 200 -
# 2025-09-29 18:09:21,092 - werkzeug - INFO - 127.0.0.1 - - [29/Sep/2025 18:09:21] "GET /favicon.ico HTTP/1.1" 404 -
# 2025-09-29 18:11:02,986 - __main__ - INFO - Processing request: file=alice.pdf, engine=tesseract, lang=eng, quality=standard, preprocess=True, format=docx
# 2025-09-29 18:11:02,986 - __main__ - INFO - Saved uploaded file to uploads/3e317471-0714-47aa-a996-41cd97ca78da_alice.pdf
# ...
